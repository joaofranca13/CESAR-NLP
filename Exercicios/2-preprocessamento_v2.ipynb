# %% [markdown]
# ## Leitura e Preprocessamento dos Dados

# %% [markdown]
# ### Requirements

# %%
import pandas as pd
import numpy as np
import os
import glob
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import seaborn as sns
from unidecode import unidecode
import altair as alt
import re

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/studio-lab-
# [nltk_data]     user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /home/studio-lab-
# [nltk_data]     user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### Leitura e Concatenação

# %%
path = os.getcwd()
files = glob.glob(os.path.join(path, "output/*/*.json"))

# %%
jsons = [pd.read_json(file, lines=True) for file in files]
df = pd.concat(jsons, ignore_index=True)

df["subject"] = [os.path.split(os.path.dirname(file))[-1] for file in files]

# %%
df
# Out:
#                                                 title  \
# 0   Modelagem de reforma catalítica seca de metano...
# 1   Aplicação de machine learning para apostas esp...
# 2   Social machines: a unified paradigm to describ...
# 3   Um método de aprendizagem seqüencial com filtr...
# 4   Development of machine and deep learning based...
# 5   Automação de controle de acesso por reconhecim...
# 6   Visão computacional aplicada a gestão da manut...
# 7   A machine learning-based methodology for autom...
# 8   Time Aware Sigmoid Optimization : a new learni...
# 9   Time series forecasting with deep forest regre...
# 10  Competitividade do setor exportador da economi...
# 11  Economia criativa e economia colaborativa como...
# 12  Uma análise das desigualdades dos estados bras...
# 13  Uma análise do mercado de trabalho na economia...
# 14  Feiras colaborativas e economia criativa na ci...
# 15  Outra economia acontece? A economia solidária ...
# 16  Economia colaborativa no Brasil: uma revisão s...
# 17  Uma abordagem da economia de comunhão como  es...
# 18  A competitividade internacional das Commoditie...
# 19  Impactos de longo prazo de reformas fiscais so...
# 20            Usos da fotografia analógica no design.
# 21                    Design e arte: a batalha épica.
# 22  O humor e a ludicidade do memphis no design de...
# 23  Integração das artes plásticas e arquitetura e...
# 24  Arte e artesanato na arquitetura de interiores...
# 25  O “Disco da banana”: uma análise histórico-art...
# 26  Cruzadas editoriais no Brasil e na Argentina: ...
# 27  Estética moderna do Design pernambucano: Lula ...
# 28  Lina Bo Bardi, architetto e designer: um estud...
# 29  Arquitetas no Recife : uma leitura de gênero d...
# 30  Diversidade genética de populações naturais de...
# 31  Variabilidade genética de populações remanesce...
# 32  Efeitos da fragmentação da restinga na estrutu...
# 33  Diversidade Genética populacional nas espécies...
# 34  Variação genética e a conservação do guaiamum ...
# 35  Efeitos da perturbação antrópica sobre a demog...
# 36  Variação genética em Aedes aegypti e Aedes alb...
# 37  Diversidade genética de leveduras do complexo ...
# 38  Diversidade genética, conectividade populacion...
# 39  Conectividade genética e morfológica de Mugil ...
# 40  Avaliação do impacto do Programa Mãe Coruja Pe...
# 41  Educadoras infantis: o que pensam sobre questõ...
# 42  A estratégia de saúde da família no contexto s...
# 43  Análise da relação entre gasto público per cap...
# 44  Renda, desigualdade regional e saúde infantil ...
# 45  A consulta infantil realizada por médicos da  ...
# 46  Desenvolvimento infantil e programas de estimu...
# 47  A educação infantil nas representações sociais...
# 48  Fundo social e mortalidade infantil : evidênci...
# 49  Desenvolvimento neuropiscomotor: Importância d...
# 50  O uso de aplicativo sobre aquecimento global n...
# 51    Simulação numérica de um forno de reaquecimento
# 52  Clima e produtividade da agricultura permanent...
# 53  Alvenarias de vedação em blocos cerâmicos reve...
# 54  Estudos de correlação de parâmetros térmicos e...
# 55  Utilização de metodologias para a análise térm...
# 56  Resistência do concreto após incêndio : compar...
# 57  Manchetes socioambientais: noticiabilidade e  ...
# 58  Cinética de cristalização isotérmica e não iso...
# 59  Sistema de indicadores para identificação das ...
#
#                                              abstract              subject
# 0   Estamos vivenciando o início da Era da Informa...      machinelearning
# 1   As práticas esportivas surgiram de atividades ...      machinelearning
# 2   The open, distributed approach of the Web and ...      machinelearning
# 3   Em aplicações de aprendizagem de máquina, é co...      machinelearning
# 4   Artificial intelligence-based algorithms have ...      machinelearning
# 5   Esta pesquisa tem como objetivo propor um méto...      machinelearning
# 6   O desgaste progressivo de peças rotativas como...      machinelearning
# 7   Oil refineries process hazardous substances at...      machinelearning
# 8   The correct choice of hyperparameters for the ...      machinelearning
# 9   A time series is a collection of ordered obser...      machinelearning
# 10  O objetivo desta pesquisa é analisar a competi...   economiabrasileira
# 11  Esta trabalho tem como objetivo demonstrar com...   economiabrasileira
# 12  A evolução das desigualdades entre as economia...   economiabrasileira
# 13  Dentre as diversas áreas que constituem o estu...   economiabrasileira
# 14  Este trabalho possui por escopo analisar os no...   economiabrasileira
# 15  O objetivo desta tese é analisar e interpretar...   economiabrasileira
# 16  A economia colaborativa é um tema inovador e s...   economiabrasileira
# 17  O TCM  Uma abordagem da Economia de Comunhão c...   economiabrasileira
# 18  O presente estudo tem como objetivo principal ...   economiabrasileira
# 19  Este trabalho objetiva analisar o impacto sobr...   economiabrasileira
# 20  Este trabalho tem como base a história do Desi...  bauhaus_arquitetura
# 21  Este trabalho apresenta relações históricas e ...  bauhaus_arquitetura
# 22  O presente trabalho de monografia parte do tem...  bauhaus_arquitetura
# 23  A integração das artes é um tema que vem sendo...  bauhaus_arquitetura
# 24  A arquiteta pernambucana Janete Costa (1932-20...  bauhaus_arquitetura
# 25  Este trabalho trata da compreensão do signific...  bauhaus_arquitetura
# 26  Esta tese procura contribuir com os estudos so...  bauhaus_arquitetura
# 27  Esta dissertação objetiva fazer um resgate dos...  bauhaus_arquitetura
# 28  A italiana Lina Bo Bardi foi relevante, enquan...  bauhaus_arquitetura
# 29  Este estudo investiga as arquitetas formadas n...  bauhaus_arquitetura
# 30  O bicudo do algodoeiro, Anthonomus grandis Boh...             genetica
# 31  Podocarpus sellowii, única conífera nativa do ...             genetica
# 32  Dichotomius schiffleri é uma espécie de besour...             genetica
# 33  A Floresta Atlântica tem sofrido contínuas ret...             genetica
# 34  Cardisoma guanhumi é um caranguejo terrestre i...             genetica
# 35  Uma das principais hipóteses para explicar a c...             genetica
# 36  Aedes aegypti e Aedes albopictus são espécies ...             genetica
# 37  O complexo Saccharomyces  sensu stricto  é atu...             genetica
# 38  O Mero, Epinephelus itajara, é umas das espéci...             genetica
# 39  Os padrões de estruturação populacional podem ...             genetica
# 40  As taxas de mortalidade infantil e materna são...        saudeinfantil
# 41  Este trabalho trata da relação entre gênero e ...        saudeinfantil
# 42  No Brasil, e mais especificamente, no Recife, ...        saudeinfantil
# 43  Um dos principais desafios em pauta para o SUS...        saudeinfantil
# 44  Muitos estudos na literatura econômica têm mos...        saudeinfantil
# 45  A implantação do novo modelo de atenção à saúd...        saudeinfantil
# 46  Introdução: o desenvolvimento infantil é um do...        saudeinfantil
# 47  Esta pesquisa teve como objetivo identificar a...        saudeinfantil
# 48  O objetivo desta dissertação é estudar os efei...        saudeinfantil
# 49  Ações voltadas para o acompanhamento do desenv...        saudeinfantil
# 50  Sem a veiculação do conhecimento com o context...   aquecimento_global
# 51  Este trabalho tem como objetivo apresentar um ...   aquecimento_global
# 52  Entender as reais consequências do aquecimento...   aquecimento_global
# 53  Não raramente os incêndios em edificações acom...   aquecimento_global
# 54  Os nitroimidazólicos são imidazólicos heterocí...   aquecimento_global
# 55  Alem do uso doméstico, a energia solar possui ...   aquecimento_global
# 56  Este trabalho tem como objetivo avaliar o test...   aquecimento_global
# 57  Entendendo o Jornalismo como construção social...   aquecimento_global
# 58  A cinética de cristalização do PET e Das blend...   aquecimento_global
# 59  O presente trabalho tem como tema a discussão ...   aquecimento_global

# %%
df.describe()
# Out:
#                                                     title  \
# count                                                  60
# unique                                                 60
# top     Modelagem de reforma catalítica seca de metano...
# freq                                                    1
#
#                                                  abstract          subject
# count                                                  60               60
# unique                                                 60                6
# top     Estamos vivenciando o início da Era da Informa...  machinelearning
# freq                                                    1               10

# %% [markdown]
# ### Stopwords
#
# English and portuguese

# %%
languages = ['english', 'portuguese']

# %%
list_stop = stopwords.words(languages)
print(list_stop[:10])
print(list_stop[-10:])
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]
# ['tivessem', 'tivéssemos', 'tu', 'tua', 'tuas', 'um', 'uma', 'você', 'vocês', 'vos']

# %% [markdown]
# ### Preprocessing

# %%
corpus = df['abstract'].copy()
preprocessed_corpus = []

for abstract in corpus:
    
    # Remove all the special characters
    document = re.sub(r'\W', ' ', str(abstract))
    
    # remove all single characters
    document = re.sub(r'\s+[a-zA-Z]\s+', ' ', document)
    
    # Remove single characters from the start
    document = re.sub(r'\^[a-zA-Z]\s+', ' ', document) 
    
    # Substituting multiple spaces with single space
    document = re.sub(r'\s+', ' ', document, flags=re.I)
    
    # Removing prefixed 'b'
    document = re.sub(r'^b\s+', '', document)
    
    # Converting to Lowercase
    document = document.lower()
    
    #Normalize
    document = unidecode(document)
    
    document = document.split()
    
    document = [word for word in document if word not in list_stop and word.isalpha()]
    
    document = " ".join(document)
        
    preprocessed_corpus.append(document)

# %%
print(len(corpus))
print(len(preprocessed_corpus))
# Out:
# 60
# 60

# %% [markdown]
# ### Feature Extration

# %%
count_vect = CountVectorizer(stop_words=list_stop, min_df=0.05, max_df=0.99)
count_vect.fit(preprocessed_corpus)
# Out:
# CountVectorizer(max_df=0.99, min_df=0.05,
#                 stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours',
#                             'ourselves', 'you', "you're", "you've", "you'll",
#                             "you'd", 'your', 'yours', 'yourself', 'yourselves',
#                             'he', 'him', 'his', 'himself', 'she', "she's",
#                             'her', 'hers', 'herself', 'it', "it's", 'its',
#                             'itself', ...])

# %%
print('Tamanho do vocabulário: ', len(count_vect.vocabulary_))
counter = 0
for _, count in count_vect.vocabulary_.items():
    counter += count
    
print('Quantidade total de palavras: ', counter)
# Out:
# Tamanho do vocabulário:  572
# Quantidade total de palavras:  163306

# %% [markdown]
# #### TF-IDF

# %%
X = count_vect.transform(preprocessed_corpus)

# %%
X.shape
# Out:
# (60, 572)

# %%
tfidf_transformer = TfidfTransformer()
tfidf_transformer.fit(X)
# Out:
# TfidfTransformer()

# %%
X_tfidf = tfidf_transformer.transform(X)

# %%
X_tfidf.shape
# Out:
# (60, 572)

# %%
count_vect.get_feature_names_out()
# Out:
# array(['abordagem', 'abordagens', 'acerca', 'acesso', 'acoes', 'acordo',
#        'adultos', 'agrupamento', 'agua', 'ainda', 'alem', 'algumas',
#        'alguns', 'aliada', 'alta', 'alteracoes', 'alto', 'ambas',
#        'ambientais', 'ambiental', 'ambiente', 'ambientes', 'ambos',
#        'analisada', 'analisadas', 'analisados', 'analisar', 'analise',
#        'analises', 'ano', 'anos', 'apenas', 'apesar', 'aplicacao',
#        'apontam', 'apos', 'aprendizagem', 'apresenta', 'apresentado',
#        'apresentam', 'apresentando', 'apresentar', 'apresentaram',
#        'apresentou', 'aproximadamente', 'aquecimento', 'area', 'areas',
#        'arquitetos', 'arquitetura', 'arte', 'artes', 'artigos',
#        'artisticos', 'aspectos', 'assim', 'ate', 'atencao', 'atividade',
#        'atividades', 'atlantica', 'atraves', 'aumento', 'avaliadas',
#        'avaliados', 'avaliar', 'avanco', 'baixa', 'baixo', 'base',
#        'bases', 'basica', 'basico', 'bem', 'bens', 'boa', 'brasil',
#        'brasileira', 'brasileiras', 'brasileiro', 'brasileiros', 'buscou',
#        'cada', 'campo', 'capacidade', 'capital', 'caracteristicas',
#        'caso', 'cenario', 'cidade', 'cinco', 'coletados', 'combinacao',
#        'comparados', 'complexidade', 'complexo', 'componentes',
#        'comportamento', 'composta', 'compreende', 'compreensao',
#        'computacional', 'conclusao', 'condicao', 'condicoes', 'conjunto',
#        'consequencias', 'consequentemente', 'conservacao', 'considerada',
#        'considerando', 'constatou', 'construcao', 'consumo', 'conteudo',
#        'context', 'contexto', 'contribuir', 'contribuiu', 'controle',
#        'contudo', 'correlacao', 'crescimento', 'criacao', 'crianca',
#        'criancas', 'crise', 'criterios', 'critico', 'dada', 'dados',
#        'datasets', 'debate', 'decadas', 'deep', 'demais', 'demanda',
#        'demonstraram', 'dentre', 'dentro', 'dependente', 'desempenho',
#        'desenvolver', 'desenvolvimento', 'design', 'dessa', 'dessas',
#        'desse', 'desses', 'desta', 'destaque', 'destas', 'deste',
#        'destes', 'determinacao', 'deve', 'devem', 'devido', 'diferencas',
#        'diferenciacao', 'diferentes', 'different', 'dinamica',
#        'discussao', 'discussoes', 'disponiveis', 'dissertacao', 'disso',
#        'distancia', 'distribuicao', 'distrito', 'diversas', 'diversidade',
#        'dna', 'dois', 'duas', 'durante', 'economia', 'economias',
#        'economica', 'economico', 'economicos', 'educacao', 'efeito',
#        'efeitos', 'elementos', 'embora', 'encontra', 'encontrados',
#        'enquanto', 'entanto', 'entender', 'entendimento', 'entretanto',
#        'entrevistas', 'escala', 'espaco', 'espacos', 'especialmente',
#        'especie', 'especies', 'especificamente', 'estado', 'estados',
#        'estao', 'estimativa', 'estrategia', 'estrategias', 'estrutura',
#        'estruturacao', 'estuarios', 'estudada', 'estudar', 'estudo',
#        'estudos', 'etapa', 'evidenciando', 'exemplares', 'existencia',
#        'existente', 'familia', 'fase', 'fatores', 'fazer', 'federal',
#        'feita', 'fim', 'final', 'finalidade', 'fluxo', 'foco', 'forma',
#        'formacao', 'formas', 'frente', 'fst', 'funcao', 'fundamental',
#        'gas', 'gasto', 'genero', 'genetica', 'genico', 'geografica',
#        'geral', 'gerar', 'gestao', 'global', 'governo', 'grande',
#        'grandes', 'grupo', 'habitat', 'hipoteses', 'historia',
#        'historico', 'identificacao', 'identificar', 'ii', 'imagens',
#        'impacto', 'impactos', 'importancia', 'importante', 'importantes',
#        'incluindo', 'indicadores', 'indice', 'indices', 'individual',
#        'individuos', 'industria', 'industriais', 'industrial', 'infantil',
#        'influencia', 'influenciaram', 'informacoes', 'information',
#        'instrumento', 'interesse', 'internacional', 'investigacao',
#        'investigar', 'isolamento', 'issr', 'issrs', 'italia', 'ja',
#        'learning', 'linguagem', 'literatura', 'locais', 'local',
#        'localidades', 'loci', 'longo', 'machine', 'machines', 'maior',
#        'maiores', 'maioria', 'manejo', 'marcadores', 'marcas',
#        'mecanismos', 'mediante', 'medidas', 'meio', 'melhor', 'melhorar',
#        'menor', 'menores', 'mercado', 'meses', 'mesma', 'metodo',
#        'metodologia', 'metodos', 'microssatelites', 'model', 'modelo',
#        'modelos', 'models', 'moderna', 'modo', 'moleculares', 'momento',
#        'mortalidade', 'mostraram', 'mostrou', 'movimento', 'movimentos',
#        'mudancas', 'muitos', 'mulheres', 'mundo', 'municipios',
#        'nacionais', 'nao', 'naturais', 'natural', 'natureza',
#        'necessidade', 'nessa', 'nesse', 'neste', 'network', 'neurais',
#        'neural', 'niveis', 'nivel', 'nm', 'nordeste', 'norte', 'novas',
#        'novo', 'novos', 'numero', 'objetivo', 'objetivou', 'objeto',
#        'obra', 'observacao', 'observada', 'observado', 'observados',
#        'observou', 'obtained', 'obter', 'obtidos', 'oferecer', 'onde',
#        'oportunidades', 'outras', 'outros', 'padrao', 'padroes', 'pais',
#        'paises', 'papel', 'paraiba', 'parametros', 'parte', 'partindo',
#        'partir', 'pe', 'pecas', 'per', 'perda', 'perfil', 'performance',
#        'periodo', 'periodos', 'pernambuco', 'perspectiva', 'pesquisa',
#        'pesquisas', 'pode', 'podem', 'pois', 'polimorficos', 'politica',
#        'politicas', 'ponto', 'populacao', 'populacionais', 'populacoes',
#        'porem', 'portanto', 'possam', 'possibilidade', 'possiveis',
#        'possivel', 'possui', 'potencial', 'poucos', 'praticas',
#        'presenca', 'presente', 'pressao', 'pretende', 'primeira',
#        'primeiro', 'principais', 'principal', 'principalmente',
#        'principios', 'processo', 'processos', 'procura', 'producao',
#        'produtos', 'profissionais', 'profissional', 'programa',
#        'promocao', 'propoe', 'propor', 'proporcao', 'proposed',
#        'proposto', 'propria', 'publica', 'publicacoes', 'publicas',
#        'publico', 'quais', 'qualidade', 'qualitativa', 'quanto', 'quatro',
#        'questoes', 'reais', 'realidade', 'realizacao', 'realizada',
#        'realizado', 'recife', 'recursos', 'rede', 'redes', 'reducao',
#        'reduzir', 'regiao', 'regioes', 'regressao', 'relacao',
#        'relacionadas', 'relacoes', 'relevancia', 'relevante', 'renda',
#        'respectivamente', 'respeito', 'result', 'resultado', 'resultados',
#        'results', 'revelaram', 'revelou', 'revisao', 'revistas',
#        'sanitario', 'santa', 'sao', 'saude', 'secundarios', 'segundo',
#        'seis', 'selecionadas', 'selecionados', 'sendo', 'sentido',
#        'serie', 'series', 'servicos', 'si', 'sido', 'significativa',
#        'similares', 'sistema', 'sob', 'sobre', 'sociais', 'social',
#        'socio', 'software', 'sugere', 'sugerindo', 'sul', 'support',
#        'svm', 'tais', 'tal', 'tamanho', 'tambem', 'tanto', 'taxa',
#        'taxas', 'tecnica', 'tecnicas', 'tema', 'tematica', 'temperatura',
#        'temperaturas', 'tempo', 'tendo', 'teoria', 'teorias', 'teorico',
#        'termos', 'tese', 'teste', 'three', 'time', 'tipo', 'todas',
#        'todo', 'torna', 'torno', 'total', 'totalmente', 'trabalho',
#        'tratamento', 'tres', 'unidades', 'used', 'uso', 'utiliza',
#        'utilizacao', 'utilizada', 'utilizado', 'utilizados', 'utilizando',
#        'valores', 'variabilidade', 'variacao', 'variando', 'variaveis',
#        'varios', 'vector', 'velocidade', 'vem', 'verificar', 'verificou',
#        'vez', 'viabilidade', 'vida', 'visando', 'vista', 'way'],
#       dtype=object)

# %% [markdown]
# ### Análise das Caracteristicas textuais

# %%
sorted_X_indices = np.argsort(X.toarray(), axis=1)[:, ::-1]
sorted_Xtfidf_indices = np.argsort(X_tfidf.toarray(), axis=1)[:,::-1]

print('Termos mais comuns nos 10 primeiros documentos:')
for i in range(10):
    print(count_vect.get_feature_names_out()[sorted_X_indices[i, :3]])

print('\nTermos mais relevantes nos 10 primeiros documentos:')
for i in range(10):
    print(count_vect.get_feature_names_out()[sorted_Xtfidf_indices[i, :3]])

print('\nTermos mais relevantes na base de dados:')
mean_Xtfidf = X_tfidf.mean(axis=0)
sorted_meanXtfidf_indices = np.argsort(mean_Xtfidf)[::-1]
print(count_vect.get_feature_names_out()[sorted_meanXtfidf_indices[:3]])
# Out:
# Termos mais comuns nos 10 primeiros documentos:
# ['gas' 'modelos' 'processos']
# ['dados' 'resultados' 'regressao']
# ['social' 'machines' 'software']
# ['metodo' 'aprendizagem' 'learning']
# ['context' 'support' 'models']
# ['atraves' 'metodo' 'modelo']
# ['meio' 'imagens' 'neural']
# ['svm' 'way' 'used']
# ['network' 'different' 'three']
# ['series' 'time' 'performance']
#
# Termos mais relevantes nos 10 primeiros documentos:
# ['gas' 'modelos' 'processos']
# ['regressao' 'dados' 'possivel']
# ['social' 'machines' 'software']
# ['aprendizagem' 'metodo' 'proposto']
# ['context' 'support' 'models']
# ['acesso' 'software' 'feita']
# ['imagens' 'meio' 'network']
# ['svm' 'way' 'vector']
# ['network' 'different' 'three']
# ['series' 'time' 'performance']
#
# Termos mais relevantes na base de dados:
# [['hipoteses' 'sugere' 'polimorficos' 'contudo' 'alguns' 'adultos' 'novo'
#   'possam' 'incluindo' 'paraiba' 'sanitario' 'distrito' 'relacionadas'
#   'condicao' 'composta' 'acoes' 'natureza' 'tecnica' 'oferecer'
#   'comparados' 'acordo' 'medidas' 'finalidade' 'respectivamente'
#   'servicos' 'quais' 'populacionais' 'perspectiva' 'selecionadas'
#   'dinamica' 'estudar' 'demanda' 'presenca' 'caso' 'entretanto' 'vem'
#   'momento' 'ambos' 'tratamento' 'basico' 'alto' 'basica' 'discussoes'
#   'menores' 'deve' 'apresentado' 'termos' 'economicos' 'necessidade'
#   'fundamental' 'marcas' 'disponiveis' 'estrategias' 'coletados' 'socio'
#   'relevante' 'perda' 'microssatelites' 'encontra' 'agua' 'estudada'
#   'apresentando' 'objetivou' 'revelou' 'qualitativa' 'formas' 'variando'
#   'habitat' 'acerca' 'analisadas' 'oportunidades' 'aspectos' 'obter'
#   'realidade' 'dada' 'aproximadamente' 'avanco' 'gerar' 'similares'
#   'avaliados' 'dna' 'secundarios' 'naturais' 'si' 'mesma' 'grandes'
#   'respeito' 'mediante' 'aliada' 'observados' 'analisada' 'abordagens'
#   'gestao' 'investigacao' 'ii' 'ponto' 'destaque' 'relevancia' 'bases'
#   'procura' 'norte' 'industriais' 'contribuiu' 'individual' 'potencial'
#   'escala' 'algumas' 'meses' 'desenvolver' 'devem' 'consequencias'
#   'observacao' 'existente' 'result' 'atividades' 'realizada' 'propor'
#   'maiores' 'dissertacao' 'frente' 'consequentemente' 'conclusao'
#   'correlacao' 'viabilidade' 'mundo' 'revelaram' 'totalmente'
#   'alteracoes' 'decadas' 'considerada' 'compreende' 'geografica' 'dentre'
#   'buscou' 'moleculares' 'melhorar' 'nesse' 'portanto' 'encontrados'
#   'destas' 'qualidade' 'fatores' 'varios' 'indices' 'artisticos' 'final'
#   'embora' 'estimativa' 'mecanismos' 'realizacao' 'rede' 'partindo'
#   'existencia' 'reduzir' 'computacional' 'observou' 'entender' 'propria'
#   'porem' 'issrs' 'exemplares' 'agrupamento' 'torno' 'distancia'
#   'demonstraram' 'neurais' 'combinacao' 'influenciaram' 'apesar' 'destes'
#   'vida' 'complexidade' 'entanto' 'area' 'espaco' 'outros' 'serie'
#   'manejo' 'promocao' 'poucos' 'locais' 'especificamente' 'seis'
#   'publicas' 'natural' 'fst' 'informacoes' 'principios' 'primeiro'
#   'mudancas' 'periodos' 'capital' 'diversas' 'pecas' 'interesse' 'baixa'
#   'estuarios' 'dependente' 'way' 'boa' 'tendo' 'paises' 'crise'
#   'tematica' 'funcao' 'selecionados' 'parametros' 'especialmente'
#   'constatou' 'criterios' 'tamanho' 'brasileiro' 'apresentaram' 'apontam'
#   'segundo' 'politica' 'critico' 'possibilidade' 'padroes' 'apresentou'
#   'publicacoes' 'produtos' 'nessa' 'santa' 'indice' 'proporcao'
#   'evidenciando' 'todo' 'atencao' 'capacidade' 'modo' 'papel' 'padrao'
#   'publica' 'gasto' 'realizado' 'grupo' 'redes' 'importantes' 'apenas'
#   'apresentar' 'internacional' 'acesso' 'componentes' 'primeira' 'torna'
#   'sul' 'abordagem' 'determinacao' 'mulheres' 'cinco' 'politicas' 'duas'
#   'etapa' 'teorias' 'distribuicao' 'estrategia' 'neste' 'entrevistas'
#   'proposed' 'teste' 'vista' 'muitos' 'resultado' 'ambas' 'reais'
#   'isolamento' 'ambiental' 'municipios' 'movimentos' 'model' 'revisao'
#   'populacao' 'used' 'aplicacao' 'revistas' 'genico' 'identificacao'
#   'pesquisas' 'contribuir' 'verificar' 'foco' 'compreensao' 'historico'
#   'familia' 'sugerindo' 'onde' 'possui' 'conjunto' 'devido' 'analises'
#   'fase' 'pois' 'estrutura' 'crescimento' 'brasileiros' 'observada'
#   'pretende' 'vector' 'principal' 'pe' 'dentro' 'aprendizagem'
#   'arquitetos' 'significativa' 'baixo' 'visando' 'teorico' 'atlantica'
#   'demais' 'geral' 'datasets' 'enquanto' 'three' 'federal' 'cenario'
#   'moderna' 'nm' 'italia' 'marcadores' 'conteudo' 'entendimento'
#   'espacos' 'consumo' 'criacao' 'regressao' 'issr' 'models' 'mostraram'
#   'sentido' 'obtained' 'information' 'fazer' 'economias' 'cada' 'sido'
#   'formacao' 'influencia' 'utilizado' 'analisados' 'recursos' 'outras'
#   'menor' 'objeto' 'complexo' 'localidades' 'diferencas' 'tipo'
#   'investigar' 'alta' 'praticas' 'brasileiras' 'utilizacao' 'controle'
#   'observado' 'apresentam' 'taxa' 'profissional' 'possiveis' 'tese'
#   'results' 'avaliadas' 'desempenho' 'maioria' 'obra' 'unidades' 'teoria'
#   'melhor' 'tal' 'desses' 'economico' 'cidade' 'nivel' 'industria'
#   'nacionais' 'ambientes' 'instrumento' 'total' 'numero' 'renda'
#   'considerando' 'sob' 'dessas' 'utilizados' 'variabilidade' 'novas'
#   'pode' 'variacao' 'disso' 'bem' 'regioes' 'dessa' 'publico' 'bens'
#   'estao' 'debate' 'todas' 'vez' 'temperaturas' 'pais' 'utiliza' 'fluxo'
#   'propoe' 'indicadores' 'importancia' 'avaliar' 'linguagem' 'feita'
#   'quanto' 'contexto' 'valores' 'apos' 'metodologia' 'historia'
#   'apresenta' 'artigos' 'economica' 'gas' 'imagens' 'obtidos' 'fim'
#   'perfil' 'utilizada' 'proposto' 'crianca' 'loci' 'discussao' 'programa'
#   'verificou' 'questoes' 'quatro' 'ate' 'caracteristicas' 'parte'
#   'impactos' 'identificar' 'efeitos' 'tres' 'velocidade' 'efeito'
#   'pressao' 'genero' 'impacto' 'tais' 'different' 'uso' 'per' 'processo'
#   'literatura' 'tempo' 'artes' 'ambientais' 'deep' 'series' 'importante'
#   'principalmente' 'ano' 'diferenciacao' 'individuos' 'ja' 'presente'
#   'conservacao' 'comportamento' 'novos' 'mostrou' 'possivel' 'base'
#   'dois' 'network' 'relacoes' 'nordeste' 'desta' 'ainda' 'neural'
#   'estudos' 'estados' 'governo' 'svm' 'support' 'software' 'aumento'
#   'industrial' 'grande' 'longo' 'time' 'estruturacao' 'modelos' 'periodo'
#   'metodos' 'condicoes' 'temperatura' 'processos' 'utilizando'
#   'profissionais' 'ambiente' 'variaveis' 'tanto' 'niveis' 'tecnicas'
#   'reducao' 'durante' 'diferentes' 'performance' 'taxas' 'podem'
#   'sociais' 'machines' 'construcao' 'mercado' 'assim' 'global'
#   'brasileira' 'desse' 'principais' 'deste' 'anos' 'especies' 'producao'
#   'context' 'regiao' 'atividade' 'campo' 'criancas' 'tema' 'maior'
#   'sendo' 'analisar' 'partir' 'estado' 'areas' 'sistema' 'diversidade'
#   'elementos' 'local' 'especie' 'movimento' 'brasil' 'arte' 'forma'
#   'metodo' 'pesquisa' 'recife' 'arquitetura' 'alem' 'meio' 'relacao'
#   'educacao' 'machine' 'tambem' 'modelo' 'mortalidade' 'pernambuco'
#   'objetivo' 'social' 'sao' 'resultados' 'analise' 'nao' 'aquecimento'
#   'learning' 'estudo' 'atraves' 'dados' 'sobre' 'desenvolvimento'
#   'trabalho' 'infantil' 'economia' 'populacoes' 'design' 'saude'
#   'genetica']]

# %% [markdown]
# ### Visualisation

# %%
p = pairwise_distances(np.argsort(X_tfidf.toarray(), axis=0)[:,::-1], metric='euclidean')
plt.imshow(p, interpolation='nearest')
plt.colorbar()

# %%
tfidf_df = pd.DataFrame(X_tfidf.toarray(), index=df['subject'], columns=count_vect.get_feature_names_out())
tfidf_df = tfidf_df.groupby('subject').mean()
tfidf_df.head()
# Out:
#                      abordagem  abordagens   acerca   acesso   acoes  \
# subject
# aquecimento_global    0.000000    0.000000  0.00000  0.00000  0.0000
# bauhaus_arquitetura   0.000000    0.011741  0.00000  0.00000  0.0000
# economiabrasileira    0.021360    0.011750  0.01355  0.00000  0.0000
# genetica              0.000000    0.000000  0.00830  0.00000  0.0083
# machinelearning       0.007304    0.008197  0.00000  0.03474  0.0000
#
#                        acordo   adultos  agrupamento      agua    ainda  ...  \
# subject                                                                  ...
# aquecimento_global   0.000000  0.000000     0.000000  0.023096  0.00000  ...
# bauhaus_arquitetura  0.000000  0.000000     0.000000  0.000000  0.00000  ...
# economiabrasileira   0.009807  0.000000     0.000000  0.000000  0.04893  ...
# genetica             0.005832  0.021063     0.038643  0.000000  0.00490  ...
# machinelearning      0.000000  0.000000     0.000000  0.000000  0.00000  ...
#
#                      velocidade       vem  verificar  verificou       vez  \
# subject
# aquecimento_global      0.07388  0.000000   0.000000   0.026850  0.000000
# bauhaus_arquitetura     0.00000  0.010454   0.000000   0.006976  0.000000
# economiabrasileira      0.00000  0.000000   0.009285   0.030750  0.007982
# genetica                0.00000  0.000000   0.024262   0.000000  0.033341
# machinelearning         0.00000  0.000000   0.009304   0.000000  0.024264
#
#                      viabilidade      vida   visando     vista       way
# subject
# aquecimento_global      0.026270  0.010785  0.038725  0.007353  0.000000
# bauhaus_arquitetura     0.000000  0.007638  0.000000  0.021030  0.000000
# economiabrasileira      0.000000  0.000000  0.000000  0.000000  0.000000
# genetica                0.007747  0.000000  0.005482  0.012334  0.000000
# machinelearning         0.000000  0.009304  0.009816  0.000000  0.042292
#
# [5 rows x 572 columns]

# %%
tfidf_df = tfidf_df.stack().reset_index()
tfidf_df.head()
# Out:
#               subject     level_1    0
# 0  aquecimento_global   abordagem  0.0
# 1  aquecimento_global  abordagens  0.0
# 2  aquecimento_global      acerca  0.0
# 3  aquecimento_global      acesso  0.0
# 4  aquecimento_global       acoes  0.0

# %%
tfidf_df = tfidf_df.rename(columns={0:'TFIDF', 'subject': 'Tema','level_1': 'Termo'})
tfidf_df
# Out:
#                     Tema        Termo     TFIDF
# 0     aquecimento_global    abordagem  0.000000
# 1     aquecimento_global   abordagens  0.000000
# 2     aquecimento_global       acerca  0.000000
# 3     aquecimento_global       acesso  0.000000
# 4     aquecimento_global        acoes  0.000000
# ...                  ...          ...       ...
# 3427       saudeinfantil  viabilidade  0.000000
# 3428       saudeinfantil         vida  0.011567
# 3429       saudeinfantil      visando  0.000000
# 3430       saudeinfantil        vista  0.008025
# 3431       saudeinfantil          way  0.000000
#
# [3432 rows x 3 columns]

# %%
top_tfidf = tfidf_df.sort_values(by=['Tema','TFIDF'], ascending=[True,False]).groupby(['Tema']).head(3)
top_tfidf
# Out:
#                      Tema            Termo     TFIDF
# 45     aquecimento_global      aquecimento  0.170861
# 524    aquecimento_global      temperatura  0.089659
# 501    aquecimento_global          sistema  0.084931
# 716   bauhaus_arquitetura           design  0.256469
# 621   bauhaus_arquitetura      arquitetura  0.138594
# 622   bauhaus_arquitetura             arte  0.121672
# 1321   economiabrasileira         economia  0.236225
# 1287   economiabrasileira  desenvolvimento  0.080561
# 1221   economiabrasileira       brasileira  0.075753
# 1957             genetica         genetica  0.298499
# 2123             genetica       populacoes  0.253155
# 1915             genetica          especie  0.126127
# 2577      machinelearning         learning  0.172064
# 2585      machinelearning          machine  0.143562
# 2403      machinelearning          context  0.106369
# 3346        saudeinfantil            saude  0.289989
# 3134        saudeinfantil         infantil  0.248289
# 3188        saudeinfantil      mortalidade  0.131956

# %%
# adding a little randomness to break ties in term ranking
top_tfidf_plusRand = top_tfidf.copy()
top_tfidf_plusRand['TFIDF'] = top_tfidf_plusRand['TFIDF'] + np.random.rand(top_tfidf.shape[0])*0.0001

# base for all visualizations, with rank calculation
base = alt.Chart(top_tfidf_plusRand).encode(
    x = 'rank:O',
    y = 'Tema:N'
).transform_window(
    rank = "rank()",
    sort = [alt.SortField("TFIDF", order="descending")],
    groupby = ["Tema"],
)

# heatmap specification
heatmap = base.mark_rect().encode(
    color = 'TFIDF:Q'
)

# text labels, white for darker heatmap colors
text = base.mark_text(baseline='middle').encode(
    text = 'Termo:N',
    color = alt.condition(alt.datum.TFIDF >= 0.2, alt.value('white'), alt.value('black'))
)

# display the three superimposed visualizations
(heatmap + text).properties(width = 600)
# Out:
# alt.LayerChart(...)
